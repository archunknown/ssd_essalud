# %%
# Ver TODOS los valores únicos de DES_ACT y su relación con DES_SER vacío
print("=== Todos los DES_ACT unicos ===")
print(df_at['DES_ACT'].value_counts())
print()
# Cruce: para las filas de "Consultas", ¿DES_SER tiene valor?
print("=== DES_SER cuando DES_ACT = 'Consultas' ===")
mask = df_at['DES_ACT'] == 'Consultas'
print(df_at[mask]['DES_SER'].value_counts().head())
print("Vacios en este subconjunto:", (df_at[mask]['DES_SER'] == '').sum(), "de", mask.sum())
# Out:
# === Todos los DES_ACT unicos ===
# DES_ACT
# Consultas            11845
# Consultan.Serv.      11714
# Nro.Cons.Funcio      10584
# Horas Prog.          10564
# Hras.Efec.(Eje)      10561
# Nro.Medicos          10518
# Nro.Cons.Fisico      10387
# Consultan.Estab       5691
# Consultan Nuev        5587
# N.Cit. C. Ext         5127
# N. Deser C.Ext        3318
# Num.Pac.C.C.D.        1087
# Num.Pac.Reing         1071
# Num.P.N.C.D.          1034
# NÂºDÃ­as Prom.Dif      912
# Name: count, dtype: int64
#
# === DES_SER cuando DES_ACT = 'Consultas' ===
# DES_SER
# Medicina       5677
# Ginecologia    2084
# Cirugia        1990
# Pediatria      1935
# Obstetricia     159
# Name: count, dtype: int64
# Vacios en este subconjunto: 0 de 11845
